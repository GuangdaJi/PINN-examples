# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../result/tx_PINN.csv').values

# %%
t, x = data[:,0].reshape(-1), data[:,1].reshape(-1)

# %%
import numpy as np 
x2 = np.cos(t)

# %%
plt.plot(t,x2-x)
# plt.plot(t,x2)
